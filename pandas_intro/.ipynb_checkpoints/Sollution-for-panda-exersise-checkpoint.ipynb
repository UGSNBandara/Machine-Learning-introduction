# %%
# Import pandas

# %%
import pandas as pd

# %%
color = pd.Series(["Yello", "Orange", "Red"])

# %%
color
# Out:
# 0     Yello
# 1    Orange
# 2       Red
# dtype: object

# %%
cars = pd.Series(["BMW", "GTR", "Civic"])

# %%
cars
# Out:
# 0      BMW
# 1      GTR
# 2    Civic
# dtype: object

# %%
car_sale = pd.read_csv("car-sales.csv")

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sale.to_csv("Exported_same_car_sale.csv")

# %%
car_exported_csv = pd.read_csv("Exported_same_car_sale.csv")

# %%
car_exported_csv
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors        Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_sale.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sale.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
num = pd.Series([2,5,4,7,8,8,6,5,9,1,5])

# %%
num.mean()
# Out:
# 5.454545454545454

# %%
num.sum()
# Out:
# 60

# %%
car_sale.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sale.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sale.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sale.loc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sale.iloc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sale["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sale["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_sale[car_sale["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sale["Make"],car_sale["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_grouped = car_sale.groupby(['Make','Doors'])

# %%
print(car_grouped)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_grouped.sum()
# Out:
#                        Colour  Odometer (KM)                           Price
# Make   Doors
# BMW    5                Black          11179                     $22,000.00
# Honda  4          RedBlueBlue         188335  $5,000.00 $7,500.00 $7,000.00
# Nissan 4           WhiteWhite         244695            $3,500.00 $9,700.00
# Toyota 3                 Blue          32549                      $7,000.00
#        4      WhiteGreenWhite         309256  $4,000.00 $4,500.00 $6,250.00

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
car_sale["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sale = pd.read_csv("car-sales.csv")

# %%
car_sale["Price"] = car_sale.Price.replace('\D', '', regex=True).astype(int)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sale["Price"] = car_sale["Price"]/100

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sale["Price"] = car_sale["Price"].convert_dtypes(int)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sale["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sale["Make"] = car_sale["Make"].str.lower()

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
missing_car_sale = pd.read_csv("car-sales-missing-data.csv")

# %%
missing_car_sale
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#NaA for the missing datas

# %%
missing_car_sale["Odometer"].fillna(missing_car_sale["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
missing_car_sale
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_car_sale["Odometer"] = missing_car_sale["Odometer"].fillna(missing_car_sale["Odometer"].mean())

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
missing_car_sale.dropna(inplace=True)

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
missing_car_sale["Seats"] = [3,3,3,3,3,3]

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      3
# 1   Honda    Red   87899.000000    4.0   $5,000      3
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3
# 3     BMW  Black   11179.000000    5.0  $22,000      3
# 4  Nissan  White  213095.000000    4.0   $3,500      3
# 5  Toyota  Green   92302.666667    4.0   $4,500      3

# %%
import random

listR = []
for i in range(6):
    listR.append(round(random.uniform(1.3,4.5),2))

# %%
missing_car_sale["Engin Size"] = listR

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size
# 0  Toyota  White  150043.000000    4.0   $4,000      3        3.34
# 1   Honda    Red   87899.000000    4.0   $5,000      3        3.35
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3        2.99
# 3     BMW  Black   11179.000000    5.0  $22,000      3        1.77
# 4  Nissan  White  213095.000000    4.0   $3,500      3        2.57
# 5  Toyota  Green   92302.666667    4.0   $4,500      3        4.32

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size
# 0  Toyota  White  150043.000000    4.0   $4,000      3        3.34
# 1   Honda    Red   87899.000000    4.0   $5,000      3        3.35
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3        2.99
# 3     BMW  Black   11179.000000    5.0  $22,000      3        1.77
# 4  Nissan  White  213095.000000    4.0   $3,500      3        2.57
# 5  Toyota  Green   92302.666667    4.0   $4,500      3        4.32

# %%
missing_car_sale["Price per Km"] = 150

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size  \
# 0  Toyota  White  150043.000000    4.0   $4,000      3        3.34
# 1   Honda    Red   87899.000000    4.0   $5,000      3        3.35
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3        2.99
# 3     BMW  Black   11179.000000    5.0  $22,000      3        1.77
# 4  Nissan  White  213095.000000    4.0   $3,500      3        2.57
# 5  Toyota  Green   92302.666667    4.0   $4,500      3        4.32
#
#    Price per Km
# 0           150
# 1           150
# 2           150
# 3           150
# 4           150
# 5           150

# %%
missing_car_sale.drop("Price per Km", axis=1)
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size
# 0  Toyota  White  150043.000000    4.0   $4,000      3        3.34
# 1   Honda    Red   87899.000000    4.0   $5,000      3        3.35
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3        2.99
# 3     BMW  Black   11179.000000    5.0  $22,000      3        1.77
# 4  Nissan  White  213095.000000    4.0   $3,500      3        2.57
# 5  Toyota  Green   92302.666667    4.0   $4,500      3        4.32

# %%
missing_car_sale.sample(frac = 1)
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size  \
# 1   Honda    Red   87899.000000    4.0   $5,000      3        3.35
# 3     BMW  Black   11179.000000    5.0  $22,000      3        1.77
# 0  Toyota  White  150043.000000    4.0   $4,000      3        3.34
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3        2.99
# 5  Toyota  Green   92302.666667    4.0   $4,500      3        4.32
# 4  Nissan  White  213095.000000    4.0   $3,500      3        2.57
#
#    Price per Km
# 1           150
# 3           150
# 0           150
# 2           150
# 5           150
# 4           150

# %%
missing_car_sale.reset_index(drop=True)
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size  \
# 0  Toyota  White  150043.000000    4.0   $4,000      3        3.34
# 1   Honda    Red   87899.000000    4.0   $5,000      3        3.35
# 2  Toyota   Blue   92302.666667    3.0   $7,000      3        2.99
# 3     BMW  Black   11179.000000    5.0  $22,000      3        1.77
# 4  Nissan  White  213095.000000    4.0   $3,500      3        2.57
# 5  Toyota  Green   92302.666667    4.0   $4,500      3        4.32
#
#    Price per Km
# 0           150
# 1           150
# 2           150
# 3           150
# 4           150
# 5           150

# %%
## have avoid repating index column again

# %%
missing_car_sale["Odometer"] = missing_car_sale["Odometer"].apply(lambda x : x*0.62137119)

# %%
missing_car_sale
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engin Size  \
# 0  Toyota  White   93232.397461    4.0   $4,000      3        3.34
# 1   Honda    Red   54617.906230    4.0   $5,000      3        3.35
# 2  Toyota   Blue   57354.217827    3.0   $7,000      3        2.99
# 3     BMW  Black    6946.308533    5.0  $22,000      3        1.77
# 4  Nissan  White  132411.093733    4.0   $3,500      3        2.57
# 5  Toyota  Green   57354.217827    4.0   $4,500      3        4.32
#
#    Price per Km
# 0           150
# 1           150
# 2           150
# 3           150
# 4           150
# 5           150

# %%
missing_car_sale.rename(columns={"Odometer miles" : "Odometer (miles)"}, inplace=True)

# %%
missing_car_sale
# Out:
#      Make Colour  Odometer (miles)  Doors    Price  Seats  Engin Size  \
# 0  Toyota  White      93232.397461    4.0   $4,000      3        3.34
# 1   Honda    Red      54617.906230    4.0   $5,000      3        3.35
# 2  Toyota   Blue      57354.217827    3.0   $7,000      3        2.99
# 3     BMW  Black       6946.308533    5.0  $22,000      3        1.77
# 4  Nissan  White     132411.093733    4.0   $3,500      3        2.57
# 5  Toyota  Green      57354.217827    4.0   $4,500      3        4.32
#
#    Price per Km
# 0           150
# 1           150
# 2           150
# 3           150
# 4           150
# 5           150
